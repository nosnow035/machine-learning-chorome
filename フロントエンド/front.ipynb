# %%
{
  "manifest_version": 3,
  "name": "ふりがなAIデモ (Colab連携)",
  "version": "1.0",
  "description": "選択したテキストにAIでフリガナを振ります。",

  "background": {
    "service_worker": "background.js"
  },

  "permissions": [
    "contextMenus",
    "activeTab",
    "scripting"
  ],

  "host_permissions": [
    "https://piacular-semisocialistically-aviana.ngrok-free.dev/"
  ]
}
